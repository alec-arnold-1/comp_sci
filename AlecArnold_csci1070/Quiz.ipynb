# %%
bday = "March"
months = ["January","February","March","April","May","June","July","August","September","October","November","December"]
for month in months:
    if month == bday:
        print(month + " is my birthday.")
# Out:
# March is my birthday.

# %% [markdown]
# ![quiz0.png](attachment:d37d376e-3c60-4c16-b38d-8af56b99a1c1.png)

# %% [markdown]
# My tree structure is what it is because the repositories are comp_sci and csci_1070. The sub folders are the ipnyb checkpoints and the AlecArnold_cssci1070 folder which has my notes in it. The csci_1070 repository's local folders are week_01 and week_02.
