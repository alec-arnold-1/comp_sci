# %% [markdown]
# # Warm up 2/12

# %% [markdown]
# Use boolean indexing to filter the titanic dataset so you have a dataframe with only users who departed from southhampton

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('titanic_test_data.csv')

# origin_array2 = df['Embarked'] == 'S'

df[df['Embarked'] == 'S']
# Out:
#      PassengerId  Pclass                                          Name  \
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# 5            897       3                    Svensson, Mr. Johan Cervin
# 7            899       2                  Caldwell, Mr. Albert Francis
# ..           ...     ...                                           ...
# 409         1301       3                     Peacock, Miss. Treasteall
# 412         1304       3                Henriksson, Miss. Jenny Lovisa
# 413         1305       3                            Spector, Mr. Woolf
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
#
#         Sex   Age  SibSp  Parch              Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # Scales of measurement

# %% [markdown]
# Nominal: Categories that do not have a natural order. Ex: blood type, zip code, race
#
# Ordinal: Categories where order matters but the difference between them is neither clear nor even. Ex: satisfaction scores, happiness level from 1-10
#
# Interval: There is order and the difference between two values is meaningful Ex: TEmperature(Celsius and Fahrenheit), credit scores, pH
#
# Ratio: The same as intervel except it has a concept of 0. There are no negative numbers. Ex: concentration, Kelvin, weight

# %% [markdown]
# # Statistics in python

# %% [markdown]
# * Central Tendency - represents the center point or "typical" value of a dataset
# * As a result, our rule of thumb is to replace nul values with the mean when the data is normally distributed and replace null values with the median when the data is skewed
